# %% [markdown]
# ## Online Food

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"D:/Download/Blacked/archive/onlinefoods.csv")

# %%
data.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
data.shape
# Out:
# (388, 13)

# %% [markdown]
# ## Task
# Delete Redundant Column
#
# Dropping duplicates
#
# Remove the NaN values from the datasets
#
# check for some more Transformation

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
columns_to_keep=['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
       'Educational Qualifications', 'Family size','Pin code', 'Output', 'Feedback']
columns_to_drop=['latitude', 'longitude','Unnamed: 12']

# %%
len(columns_to_keep)
# Out:
# 10

# %%
len(columns_to_drop)
# Out:
# 3

# %%
data.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %% [markdown]
# ## Task 1

# %%
modified_data=data[columns_to_keep]

# %%
data.drop(columns= columns_to_drop,inplace=True)

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  Pin code Output   Feedback
# 0                Post Graduate            4    560001    Yes   Positive
# 1                     Graduate            3    560009    Yes   Positive
# ...

# %%
## Renaming column

# %%
data.rename(columns={"Monthly Income":"Monthly Salary"}, inplace=True)

# %%
data
# Out:
#      Age  Gender Marital Status Occupation  Monthly Salary  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  Pin code Output   Feedback
# 0                Post Graduate            4    560001    Yes   Positive
# 1                     Graduate            3    560009    Yes   Positive
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(103)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
## remove nan vakue

# %%
data.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Salary                0
# Educational Qualifications    0
# Family size                   0
# Pin code                      0
# Output                        0
# Feedback                      0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Salary                0
# Educational Qualifications    0
# Family size                   0
# Pin code                      0
# Output                        0
# Feedback                      0
# dtype: int64

# %%
## we need age in months

# %%
data["Age (Months)"]=data["Age"]*12

# %%
data.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Salary  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  Pin code Output   Feedback  \
# 0              Post Graduate            4    560001    Yes   Positive
# 1                   Graduate            3    560009    Yes   Positive
# 2              Post Graduate            3    560017    Yes  Negative
# 3                   Graduate            6    560019    Yes   Positive
# 4              Post Graduate            4    560010    Yes   Positive
#
#    Age (Months)
# 0           240
# 1           288
# 2           264
# 3           264
# 4           264

# %%
data["Gender"]=data["Gender"].apply(lambda x: "F" if x == "Female" else "M")

# %%
data
# Out:
#      Age Gender Marital Status Occupation   Monthly Salary  \
# 0     20      F         Single    Student        No Income
# 1     24      F         Single    Student   Below Rs.10000
# 2     22      M         Single    Student   Below Rs.10000
# 3     22      F         Single    Student        No Income
# 4     22      M         Single    Student   Below Rs.10000
# ..   ...    ...            ...        ...              ...
# 355   21      M         Single    Student        No Income
# 363   31      M        Married   Employee  More than 50000
# 369   30      M        Married   Employee  More than 50000
# 374   21      M         Single    Student        No Income
# 386   23      M         Single    Student   Below Rs.10000
#
#     Educational Qualifications  Family size  Pin code Output   Feedback  \
# 0                Post Graduate            4    560001    Yes   Positive
# 1                     Graduate            3    560009    Yes   Positive
# ...

# %%
## if family size>3 then is large else small

# %%
data["Family size"]=data["Family size"].apply(lambda x: "Small" if x <=3 else "Large")

# %%
## yes = 1, No=0

# %%
data["Output"]=data["Output"].apply(lambda x: "1" if x == "Yes" else "0")

# %%
data
# Out:
#      Age Gender Marital Status Occupation   Monthly Salary  \
# 0     20      F         Single    Student        No Income
# 1     24      F         Single    Student   Below Rs.10000
# 2     22      M         Single    Student   Below Rs.10000
# 3     22      F         Single    Student        No Income
# 4     22      M         Single    Student   Below Rs.10000
# ..   ...    ...            ...        ...              ...
# 355   21      M         Single    Student        No Income
# 363   31      M        Married   Employee  More than 50000
# 369   30      M        Married   Employee  More than 50000
# 374   21      M         Single    Student        No Income
# 386   23      M         Single    Student   Below Rs.10000
#
#     Educational Qualifications Family size  Pin code Output   Feedback  \
# 0                Post Graduate       Large    560001      1   Positive
# 1                     Graduate       Small    560009      1   Positive
# ...

# %%
data.to_excel("Clean Food Data.xlsx", index=False)
